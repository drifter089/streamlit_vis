# %%
import pypsa

# %%
n = pypsa.Network("./new_data/NG/networks/elec_s_6_ec_lcopt_Co2L-4H.nc");
n_h2= pypsa.Network("./new_data/WITH_H2/networks/elec_s_6_ec_lcopt_Co2L-4H.nc");
# Out:
# INFO:pypsa.io:Imported network elec_s_6_ec_lcopt_Co2L-4H.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores
# INFO:pypsa.io:Imported network elec_s_6_ec_lcopt_Co2L-4H.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n.plot()
# Out:
# (<matplotlib.collections.PatchCollection at 0x2c14170c2b0>,
# ...
#  <matplotlib.collections.LineCollection at 0x2c14170f880>)
# e:\installs\envs\pypsa-earth\lib\site-packages\cartopy\mpl\style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %%
n_h2.plot()
# Out:
# (<matplotlib.collections.PatchCollection at 0x2c141798760>,
# ...
#  <matplotlib.collections.LineCollection at 0x2c14179aaa0>)
# e:\installs\envs\pypsa-earth\lib\site-packages\cartopy\mpl\style.py:76: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %%
print(n.statistics())
# Out:
#                                 Capacity Factor  Capital Expenditure  \
#             carrier
# Generator   Combined-Cycle Gas         0.718385         1.417680e+08
#             Oil                        0.000000         8.208971e+07
#             Onshore Wind               0.159914         1.182236e+05
#             Open-Cycle Gas             0.371560         2.715611e+08
#             Solar                      0.174463         4.690787e+08
#             load                       0.000000         0.000000e+00
# Line        AC                         0.290510         2.306564e+08
# Link        H2 electrolysis                 NaN         0.000000e+00
#             H2 fuel cell                    NaN         0.000000e+00
#             battery charger                 NaN         0.000000e+00
#             battery discharger              NaN         0.000000e+00
# Load        -                               NaN                  NaN
# ...

# %%
print(n_h2.statistics())
# Out:
#                                 Capacity Factor  Capital Expenditure  \
#             carrier
# Generator   Combined-Cycle Gas         0.718385         1.417680e+08
#             Oil                        0.000000         8.208971e+07
#             Onshore Wind               0.159914         1.182236e+05
#             Open-Cycle Gas             0.371561         2.715611e+08
#             Solar                      0.174463         4.690787e+08
#             load                       0.000000         0.000000e+00
# Line        AC                         0.356739         2.306660e+08
# Link        H2 electrolysis                 NaN         0.000000e+00
#             H2 fuel cell                    NaN         0.000000e+00
#             H2 pipeline                     NaN         0.000000e+00
#             battery charger                 NaN         0.000000e+00
#             battery discharger              NaN         0.000000e+00
# ...

# %%
n.statistics()
# Out:
#                                 Capacity Factor  Capital Expenditure  \
#             carrier
# Generator   Combined-Cycle Gas         0.718385         1.417680e+08
#             Oil                        0.000000         8.208971e+07
#             Onshore Wind               0.159914         1.182236e+05
#             Open-Cycle Gas             0.371560         2.715611e+08
#             Solar                      0.174463         4.690787e+08
#             load                       0.000000         0.000000e+00
# Line        AC                         0.290510         2.306564e+08
# Link        H2 electrolysis                 NaN         0.000000e+00
#             H2 fuel cell                    NaN         0.000000e+00
#             battery charger                 NaN         0.000000e+00
#             battery discharger              NaN         0.000000e+00
# Load        -                               NaN                  NaN
# ...
